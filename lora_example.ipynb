# %%
from lora_example import LoRATransformer
from torch.utils.data import DataLoader, TensorDataset
from pytorch_lightning import Trainer
import torch

# Prepare synthetic data
x = torch.randint(0, 1000, (500, 10))
y = torch.randint(0, 1000, (500, 10))
dataloader = DataLoader(TensorDataset(x, y), batch_size=32)

# Train model
model = LoRATransformer()
trainer = Trainer(max_epochs=5)
trainer.fit(model, dataloader)
# Out:
# d:\Projetos\ProjetosPessoais\FIAP-Pos\redes-neurais-lora\venv\Lib\site-packages\torch\_subclasses\functional_tensor.py:279: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from lora_example import LoRATransformer
#       2 from torch.utils.data import DataLoader, TensorDataset
#       3 from pytorch_lightning import Trainer
#
# File d:\Projetos\ProjetosPessoais\FIAP-Pos\redes-neurais-lora\lora_example.py:3
#       1 import torch
#       2 import torch.nn as nn
# ----> 3 import pytorch_lightning as pl
#       6 class LoRALinear(nn.Module):
# ...
